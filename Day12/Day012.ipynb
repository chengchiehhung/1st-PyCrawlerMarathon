# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text)
# print(soup.prettify())
data = []
for d in soup.find_all(class_="r-ent"):
    try:
        
        post={}
        r = BeautifulSoup(requests.get('https://www.ptt.cc{}'.format(d.find(class_='title').find('a')['href'])).text)
        post['標題'] = r.find_all(class_='article-meta-value')[2].text.replace('\t', '').replace('\n', '')
        post['作者'] = r.find(class_='article-meta-value').text
        post['時間'] = r.find_all(class_='article-meta-value')[-1].text
        
        data.append(post)
    except:
        continue

data = sorted(data, key=lambda k: k['時間']) 
for i in data:
    print(i['時間'])
print('------------------')
print('最新')
print('------------------')
print('標題：',data[-1]['標題'])
print('作者：',data[-1]['作者'])
print('時間：',data[-1]['時間'])
# Out:
# Sun Oct 17 18:50:47 2021
# Tue Oct 26 19:42:46 2021
# Tue Oct 26 22:35:05 2021
# Tue Oct 26 23:43:38 2021
# Wed Oct 27 00:08:30 2021
# ------------------
# 最新
# ------------------
# 標題： [討論] 誰是公牛一哥？
# 作者： SincereBob (誠實老包)
# 時間： Wed Oct 27 00:08:30 2021

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
for d in soup.find_all(class_="r-ent"):
   
    try:
       
        r = BeautifulSoup(requests.get('https://www.ptt.cc{}'.format(d.find(class_='title').find('a')['href'])).text)
        print('標題：',r.find_all(class_='article-meta-value')[2].text.replace('\t', '').replace('\n', ''))
        print('作者：',r.find(class_='article-meta-value').text)
        print('時間：',r.find_all(class_='article-meta-value')[-1].text)
        
    except:
        continue
    print('\n')
# Out:
# 標題： [新聞] 公牛創1997年後最佳開局 德羅展：現在就
# 作者： Gotham (萬惡之城)
# 時間： Tue Oct 26 22:35:05 2021
#
#
# 標題： [花邊] 讓人想起MVP羅斯 莫蘭特戰洛城雙雄獲前輩
# 作者： thnlkj0665 (灰色地帶)
# 時間： Tue Oct 26 23:43:38 2021
#
#
# 標題： [討論] 誰是公牛一哥？
# 作者： SincereBob (誠實老包)
# 時間： Wed Oct 27 00:08:30 2021
#
#
# 標題： [情報] SEASON Schedule October / November 21–22
# 作者： laptic (靜夜聖林彼岸花)
# 時間： Sun Oct 17 18:50:47 2021
#
#
# 標題： [公告] NBA 板 開始舉辦樂透!
# 作者： Induction
# 時間： Tue Oct 26 19:42:46 2021

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
#PTT八卦版
url2 = 'https://www.ptt.cc/bbs/Gossiping/index.html'
#八卦版須加cookies
r1 = requests.get(url2,cookies={'over18':'1'})
soup1 = BeautifulSoup(r1.text)
#print(soup1.prettify())

data2=[]
for d in soup1.find_all(class_="r-ent"):
   
    try:
        post1={}
        r1 = BeautifulSoup(requests.get('https://www.ptt.cc{}'.format(d.find('a')['href']),cookies={'over18':'1'}).text)
        
        post1['標題'] = r1.find_all(class_='article-meta-value')[2].text.replace('\t', '').replace('\n', '')
        post1['作者'] = r1.find(class_='article-meta-value').text
        post1['時間'] = r1.find_all(class_='article-meta-value')[-1].text
        
        data2.append(post1)
        print('標題：',post1['標題'])
        print('作者：',post1['作者'])
        print('時間：',post1['時間'])
        print('\n')
    
    except:
        continue
# Out:
# 標題： Re: [問卦] 安倍晉三開設YouTube帳號?
# 作者： Vladivostok (海参崴)
# 時間： Wed Oct 27 00:00:26 2021
#
#
# 標題： Re: [新聞] 快訊／美國國務卿布林肯呼籲：挺台灣「參
# 作者： kice1204 (無知真好)
# 時間： Wed Oct 27 00:00:32 2021
#
#
# 標題： [問卦] 氣泡水是不是最棒的飲料？
# 作者： Gogoro5566 (哥哥揉56)
# 時間： Wed Oct 27 00:00:58 2021
#
#
# 標題： [問卦] 你各位該買骨傳導耳機了吧?
# 作者： Kaoos (卡歐思)
# 時間： Wed Oct 27 00:02:09 2021
#
#
# 標題： [問卦] 遇到24歲以上的女生要叫阿姨嗎
# 作者： KENDO777 (KENDO777)
# 時間： Wed Oct 27 00:02:10 2021
#
#
# 標題： [問卦] 議員跟立委哪個比較爽???
# 作者： kkwwee (小連)
# 時間： Wed Oct 27 00:02:24 2021
#
#
# 標題： [問卦] 盟軍駐台是否要重新設置慰安婦/軍中831
# 作者： Huffman (David)
# 時間： Wed Oct 27 00:04:03 2021
#
#
# 標題： Re: [問卦] 近年男子偶像團體有嗎?!
# 作者： OPPAISuki (OPPAISuki)
# 時間： Wed Oct 27 00:05:17 2021
#
#
# 標題： [問卦] 日本所有皇族都是住在赤坂御所嗎？
# 作者： bluebagel (果果:))
# 時間： Wed Oct 27 00:05:57 2021
#
#
# 標題： Re: [問卦] 得吃安眠藥的人生是不是很可悲
# 作者： peter891116 (..)
# 時間： Wed Oct 27 00:06:15 2021
#
#
# 標題： [問卦] 真歹勢做不成妳的人 我的魂不適合妳的身
# 作者： HDSM (Love Not Change  O'_'O)
# 時間： Wed Oct 27 00:06:45 2021
#
#
# 標題： [問卦] 原來我已經一個多月沒有...
# 作者： kkk1234 (Marylin4life)
# 時間： Wed Oct 27 00:07:01 2021
#
#
# 標題： [問卦] 台北帝大在帝大體系排第幾？
# 作者： TsukimiyaAyu (ㄎㄎㄎㄎㄎㄎㄎㄎㄎㄎㄎ)
# 時間： Wed Oct 27 00:07:16 2021
#
#
# 標題： [新聞] 利用WeChat連繫犯罪難偵查 法務部：盡量
# 作者： asdf1256 (guest)
# 時間： Wed Oct 27 00:07:23 2021
#
#
# 標題： [問卦] 最近在看哪些書?? 講出來啊!!
# 作者： zz2895341 (煙大屌宅男)
# 時間： Wed Oct 27 00:08:20 2021
#
#
# 標題： [問卦]為什麼現在藝人不拍露點寫真了
# 作者： Number87 (人畜無害)
# 時間： Wed Oct 27 00:08:21 2021
#
#
# 標題： [問卦] 國產疫苗是不是當初要給館長做啊
# 作者： Doica2445 (千千千)
# 時間： Wed Oct 27 00:09:01 2021
#
#
# 標題： [問卦] 女生都喜歡美甲？
# 作者： kinjk01 (小白)
# 時間： Wed Oct 27 00:09:34 2021
#
#
# 標題： [問卦] 塔綠班幹嘛怕公投都同意？
# 作者： ae034 (gone with wind)
# 時間： Wed Oct 27 00:09:44 2021
#
#
# 標題： [問卦] 抗中保台有什麼錯呢？
# 作者： johanLarson (Rent)
# 時間： Wed Oct 27 00:09:51 2021
#
#
# 標題： [公告] 八卦板板規(2021.05.11)
# 作者： arsonlolita (蘿莉塔大魔王)
# 時間： Tue May 11 15:03:06 2021
#
#
# 標題： [協尋] (10/26更新人已找到) 10/23早上九點新北市新店朋友失聯
# 作者： Vraco0802 (Vraco)
# 時間： Sun Oct 24 01:42:39 2021
#
#
# 標題： [協尋] 發錢 需要玄鳳拯救玄鳳
# 作者： BigOwl (大貓頭)
# 時間： Mon Oct 25 23:12:21 2021
#
#
# 標題： [公告] ★☯2021年10月八卦板主徵選投票開始☯★
# 作者： ubcs (覺★青年超冒險蓋)
# 時間： Mon Oct 25 18:10:44 2021
#
#
# 標題： [公告] 手機投票教學 附圖 板主投票及活動可用
# 作者： ubcs (覺★青年超冒險蓋)
# 時間： Sat Feb  6 15:09:20 2021

# ...

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
Class = soup.find(class_="part_list_2").find_all("em")
ClassList = []

for item in Class:
    ClassList.append(item.text)
    
ClassSet = set(ClassList)
ClassList = list(ClassSet)

ClassNAList = []
for i in range(len(ClassList)):
    ClassNAList.append([])

for item in Class:
    i = ClassList.index(item.text)
    ClassNAList[i].append(item.parent.text.replace("\u3000",""))
    
ClassDict = {}
for i in range(len(ClassNAList)):
    ClassDict[ClassList[i]] = ClassNAList[i]

print(ClassDict)
# Out:
# {'社會': ['2021/10/26 20:16社會苗栗檢舉王年賺200萬！全台高手爭高額獎金案噴3倍縣府：大砍薪', '2021/10/26 19:05社會鄧佳華哀喊不想跟小玉同房律師要他放心：不用關但要做一件事', '2021/10/26 18:54社會快訊／太魯閣翻車案主嫌李義祥「60萬交保」檢方不服立提抗告', '2021/10/26 18:22社會他與小女友「體外」完事2條線要當爸超開心...岳母來電大逆轉', '2021/10/26 18:20社會富士全錄遭掏空「金額恐不只2億」檢調第二波搜索約談', '2021/10/26 18:07社會上國道邊開邊吞飯糰！台中客運司機曝原因...懲處結果出爐', '2021/10/26 17:52社會曾砍傷百萬網紅「超艾夾」！高雄「金毛」又惹事帶頭打酒客', '2021/10/26 17:50社會「跑山獸」攀進海拔1148米仁愛分局分享山域搜救經驗'], '新奇': ['2021/10/26 19:23新奇螞蟻兵洩密人類大腦3000年前因「社交」集體縮小'], '軍武': ['2021/10/26 20:02軍武空運隊連3年執行吊掛關鍵壓繩手助攻國旗面展開飄揚', '2021/10/26 19:47軍武結合降落傘工法史上最大國旗強風下成功飄揚40分鐘'], '體育': ['2021/10/26 20:04體育林益全開轟！連13年單季百安持續寫紀錄悍將5比0桃猿', '2021/10/26 19:56體育舉調教丁丁為例葉總點名他們3人接味全本土守護神', '2021/10/26 19:50體育王柏融火腿主場終戰雙安吳念庭打出生涯年本季完美收官', '2021/10/26 19:41體育赫雷拉3下打中壘包幸運安味全單局攻進2分領先兄弟', '2021/10/26 19:26體育富邦悍將球季打完秋訓統一獅有不同考量', '2021/10/26 19:21體育王維中最多再投2場葉總：可能關機不再上', '2021/10/26 18:55體育陳冠宇增爆發力多虧護齒套羅德 還有專屬口香糖', '2021/10/26 18:50體育不要讓太多人失望葉總無法想像沒有伍鐸及田澤純一', '2021/10/26 18:19體育猿獅戰「水上樂園」苦鬥曾總：工作人員最辛苦', '2021/10/26 18:18體育中信盃黑豹旗／發愛心
# ...

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
Count = []
for i in range(len(ClassDict.keys())):
    Count.append(len(ClassDict[list(ClassDict.keys())[i]]))

print("Most Category: " + str(ClassList[Count.index(max(Count))]))
# Out:
# Most Category: 體育
